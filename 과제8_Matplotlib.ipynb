# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1 ~ 3.
#
# #### 1. [1, 2, 3, 4] → [1, 4, 9, 16] 에 대응하는 Line Graph를 출력해보세요.
#
# #### 2. 1의 그래프에, Y축의 값이 마커로 표시하여 출력해보세요.
#
# #### 3. 2의 그래프에, 축의 범위를 지정하여 출력해보세요.
# (X 축 : 0, 6) (Y축 : 0, 20)

# %%
# 1 의 답을 여기에 입력해주세요.

# %%
# 2 의 답을 여기에 입력해주세요.

# %%
# 3 의 답을 여기에 입력해주세요.

# %% [markdown]
# ### 4 ~ 5.
#
# #### 4. 아래 코드에, X축과 Y축에 이름을 붙여 출력보세요.
# (X : City, Y : Number of responses)
#
# #### 5. 4의 결과에, 그래프의 제목을 붙여 출력해보세요.
# (Research result)

# %%
plt.plot(["Seoul","Busan","Daegu"], [55,65,70])

# %%
# 4 의 답을 여기에 입력해주세요.

# %%
# 5의 답을 여기에 입력해주세요.

# %% [markdown]
# ### 6 ~ 7.
#
# #### 6. 아래 내용을 만족하는 결과물을 출력해보세요.
#
# 그래프 1 : [1, 2, 3, 4] →  : [4, 7, 6, 11]
#
# 그래프 2 : [1, 2, 3, 4] →  : [2, 3, 5, 3]
#
# X 축 : Sequence
#
# Y 축 : Number of responses
#
# 제목 : Experiment result
#
# #### 7. 6의 결과에, 범례를 추가하여 출력하세요.
#
# 그래프 1 : Lion
#
# 그래프 2 : Tiger

# %%
# 3-1. 열의 합 답안을 입력해주세요.

# %% [markdown]
# ### 8~ 10.
#
# #### 8. 아래 내용을 막대 그래프로 출력해보세요.
#
# scorer = [Kane', 'Son', 'Ronaldo', 'Messi', 'Kaka', 'Lewandovski']
#
# Goals = [40, 37, 45, 57, 35, 40]
#
# X 축 : 'Scorer'
#
# Y 축 : 'Goals'
#
# 제목 : European Football Top Scorers in 2023-2024
#
#
# #### 9. 8의 막대 그래프 색을 초록색으로 바꿔 출력해보세요.
#
#
# #### 10. 9의 결과에, Y값이 막대 위에 표현되도록 바꿔 출력해보세요.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 8의 답안을 입력해주세요.

# %%
# 9의 답안을 입력해주세요.

# %%
# 10의 답안을 입력해보세요.
